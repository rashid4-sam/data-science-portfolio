# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)


# Making the prediction using X_test values
y_pred_dt = model.predict(X_test_sc)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_dt)

from sklearn.metrics import precision_score,recall_score,f1_score,classification_report,roc_auc_score

cls_dt = classification_report(y_test,y_pred_dt)
print("class_report: ",cls_dt)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.81      0.82      0.81      1273
#          Yes       0.51      0.49      0.50       485
#
#     accuracy                           0.73      1758
#    macro avg       0.66      0.66      0.66      1758
# weighted avg       0.73      0.73      0.73      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)


from imblearn.over_sampling import RandomOverSampler


oversampler = RandomOverSampler()
X_train_resampled, y_train_resampled = oversampler.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_os = DecisionTreeClassifier()
model_os.fit(X_train_resampled,y_train_resampled)

y_pred_dt_os = model_os.predict(X_test_sc)

accuracy_score(y_test,y_pred_dt_os)

cls_dt_os = classification_report(y_test,y_pred_dt_os)

print("class_report: ",cls_dt_os)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.82      0.82      0.82      1271
#          Yes       0.53      0.53      0.53       487
#
#     accuracy                           0.74      1758
#    macro avg       0.68      0.67      0.67      1758
# weighted avg       0.74      0.74      0.74      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)


from imblearn.under_sampling import RandomUnderSampler


undersampling = RandomUnderSampler()
X_train_resampled_us, y_train_resampled_us = undersampling.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_us = DecisionTreeClassifier()
model_us.fit(X_train_resampled_us,y_train_resampled_us)

y_pred_dt_us = model_us.predict(X_test_sc)

accuracy_score(y_test,y_pred_dt_us)

cls_dt_us = classification_report(y_test,y_pred_dt_us)

print("class_report: ",cls_dt_us)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.86      0.70      0.77      1286
#          Yes       0.46      0.70      0.56       472
#
#     accuracy                           0.70      1758
#    macro avg       0.66      0.70      0.66      1758
# weighted avg       0.76      0.70      0.71      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)





from imblearn.over_sampling import SMOTE


smote = SMOTE(random_state=42)
X_train_resampled_sme, y_train_resampled_sme = smote.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_sme = DecisionTreeClassifier()
model_sme.fit(X_train_resampled_sme,y_train_resampled_sme)

y_pred_dt_sme = model_sme.predict(X_test_sc)

accuracy_score(y_test,y_pred_dt_sme)

cls_dt_sme = classification_report(y_test,y_pred_dt_sme)

print("class_report: ",cls_dt_sme)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.83      0.80      0.82      1290
#          Yes       0.50      0.56      0.53       468
#
#     accuracy                           0.74      1758
#    macro avg       0.67      0.68      0.67      1758
# weighted avg       0.75      0.74      0.74      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)


from imblearn.combine import SMOTEENN


smoteen = SMOTEENN(random_state=42)
X_train_resampled_sme_enn, y_train_resampled_sme_enn = smoteen.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_sme_enn = DecisionTreeClassifier()
model_sme_enn.fit(X_train_resampled_sme_enn,y_train_resampled_sme_enn)

y_pred_dt_sme_enn = model_sme_enn.predict(X_test_sc)

accuracy_score(y_test,y_pred_dt_sme_enn)

cls_dt_sme_enn = classification_report(y_test,y_pred_dt_sme_enn)

print("class_report: ",cls_dt_sme_enn)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.88      0.72      0.79      1255
#          Yes       0.52      0.76      0.62       503
#
#     accuracy                           0.73      1758
#    macro avg       0.70      0.74      0.70      1758
# weighted avg       0.78      0.73      0.74      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)




from imblearn.over_sampling import ADASYN


adasyn = ADASYN()
X_train_resampled_ads, y_train_resampled_ads = adasyn.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_ads = DecisionTreeClassifier()
model_ads.fit(X_train_resampled_ads,y_train_resampled_ads)

y_pred_ads = model_ads.predict(X_test_sc)

accuracy_score(y_test,y_pred_ads)

cls_dt_ads = classification_report(y_test,y_pred_ads)

print("class_report: ",cls_dt_ads)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.83      0.80      0.82      1286
#          Yes       0.51      0.57      0.54       472
#
#     accuracy                           0.74      1758
#    macro avg       0.67      0.68      0.68      1758
# weighted avg       0.75      0.74      0.74      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)



from imblearn.under_sampling import AllKNN


A11 = AllKNN(sampling_strategy='auto')
X_train_resampled_a11, y_train_resampled_a11 = A11.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_a11 = DecisionTreeClassifier()
model_a11.fit(X_train_resampled_a11,y_train_resampled_a11)

y_pred_a11 = model_a11.predict(X_test_sc)

accuracy_score(y_test,y_pred_a11)


cls_dt_a11 = classification_report(y_test,y_pred_a11)

print("class_report: ",cls_dt_a11)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.91      0.62      0.74      1285
#          Yes       0.45      0.83      0.58       473
#
#     accuracy                           0.68      1758
#    macro avg       0.68      0.73      0.66      1758
# weighted avg       0.79      0.68      0.70      1758

# %%
df = pd.read_csv('CustomerChurn.csv')


df.TotalCharges = pd.to_numeric(df.TotalCharges, errors='coerce')

df.dropna(how='any',inplace=True)

X = df.drop(['customerID','Churn'],axis=1)
y = df.Churn.values


#feature encode
X = pd.get_dummies(X,columns=['gender',  'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True).astype(int)

#Split the data into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)


# We have to Feauture scale the data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)


#Implement Dt Model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)


from imblearn.under_sampling import TomekLinks


tomek = TomekLinks(sampling_strategy='majority')
X_train_resampled_tk, y_train_resampled_tk = tomek.fit_resample(X_train_sc, y_train)

from sklearn.tree import DecisionTreeClassifier
model_tk = DecisionTreeClassifier()
model_tk.fit(X_train_resampled_tk,y_train_resampled_tk)

y_pred_tk = model_tk.predict(X_test_sc)

accuracy_score(y_test,y_pred_tk)

cls_dt_tk = classification_report(y_test,y_pred_tk)

print("class_report: ",cls_dt_tk)
# Out:
# class_report:                precision    recall  f1-score   support
#
#           No       0.85      0.78      0.82      1294
#          Yes       0.50      0.61      0.55       464
#
#     accuracy                           0.74      1758
#    macro avg       0.68      0.70      0.68      1758
# weighted avg       0.76      0.74      0.75      1758

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=200, n_features=5,
                           n_informative=5, n_redundant=0,
                           random_state=0, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['a','b','c','d','e'])
df['target'] = y

# %%
df
# Out:
#             a         b         c         d         e  target
# 0   -1.519341  0.385289  0.648311  1.204945  2.342479       0
# 1   -1.201104  0.193189  0.879223  1.036656  0.994637       0
# 2    0.559513 -0.954721 -0.148043  2.560684  0.531669       1
# 3   -0.975179 -0.875320  0.336313  0.089443  1.379939       0
# 4    1.475823 -1.445329  0.271343 -0.822431  1.961805       0
# ..        ...       ...       ...       ...       ...     ...
# 195  1.364924  2.441267 -1.811650 -0.180309 -0.089983       1
# 196 -0.136510  0.340260  0.618732  3.202461 -2.504783       1
# 197  0.677838  0.990252 -1.347850  0.435248  0.000921       1
# 198 -2.018267 -0.129490  1.780441  2.254239  0.013130       0
# 199  0.864830  1.578711 -0.710822  1.318980  0.524546       1
#
# [200 rows x 6 columns]

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.drop('target',axis=1),df['target'])
# Out:
# BaggingClassifier(max_features=2)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,10))
plot_tree(bag.estimators_[0])
# Out:
# [Text(0.3333333333333333, 0.875, 'x[0] <= -0.145\ngini = 0.5\nsamples = 124\nvalue = [103, 97]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 54\nvalue = [0, 86]'),
#  Text(0.25, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[1] <= 2.659\ngini = 0.174\nsamples = 70\nvalue = [103, 11]'),
#  Text(0.41666666666666663, 0.75, '  False'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 54\nvalue = [90, 0]'),
#  Text(0.6666666666666666, 0.375, 'x[0] <= 1.069\ngini = 0.497\nsamples = 16\nvalue = [13, 11]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [0, 11]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 8\nvalue = [13, 0]')]

# %%
rfc = RandomForestClassifier(max_features=2)

rfc.fit(df.drop('target',axis=1),df['target'])

from sklearn.tree import plot_tree
plt.figure(figsize=(10,10))
plot_tree(rfc.estimators_[0])
# Out:
# [Text(0.5909090909090909, 0.9285714285714286, 'x[1] <= 0.141\ngini = 0.498\nsamples = 125\nvalue = [106, 94]'),
#  Text(0.36363636363636365, 0.7857142857142857, 'x[3] <= 3.686\ngini = 0.201\nsamples = 72\nvalue = [102, 13]'),
#  Text(0.4772727272727273, 0.8571428571428572, 'True  '),
#  Text(0.2727272727272727, 0.6428571428571429, 'x[2] <= -0.171\ngini = 0.149\nsamples = 70\nvalue = [102, 9]'),
#  Text(0.18181818181818182, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 7]'),
#  Text(0.36363636363636365, 0.5, 'x[4] <= -1.717\ngini = 0.038\nsamples = 65\nvalue = [102, 2]'),
#  Text(0.18181818181818182, 0.35714285714285715, 'x[4] <= -1.847\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09090909090909091, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2727272727272727, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5454545454545454, 0.35714285714285715, 'x[2] <= -0.068\ngini = 0.019\nsamples = 63\nvalue = [101, 1]'),
#  Text(0.45454545454545453, 0.21428571428571427, 'x[3] <= 1.764\ngini = 0.375\nsamples = 3\nvalue = [3, 1]'),
#  Text(0.36363636363636365, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]'),
#  Text(0.5454545454545454, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6363636363636364, 0.21428571428571427, 'gini = 0.0\nsamples = 60\nvalue = [98, 0]'),
#  Text(0.45454545454545453, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.8181818181818182, 0.7857142857142857, 'x[4] <= 3.05\ngini = 0.09\nsamples = 53\nvalue = [4, 81]'),
#  Text(0.7045454545454546, 0.8571428571428572, '  False'),
#  Text(0.7272727272727273, 0.6428571428571429, 'x[2] <= 0.311\ngini = 0.024\nsamples = 52\nvalue = [1, 81]'),
#  Text(0.6363636363636364, 0.5, 'gini = 0.0\nsamples = 49\nvalue = [0, 77]'),
#  Text(0.8181818181818182, 0.5, 'x[0] <= -1.186\ngini = 0.32\nsamples = 3\nvalue = [1, 4]'),
#  Text(0.7272727272727273, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9090909090909091, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 4]'),
#  Text(0.9090909090909091, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [3, 0]')]
